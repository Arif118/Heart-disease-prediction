# %% [markdown]
# <a href="https://colab.research.google.com/github/Arif118/Heart-disease-prediction/blob/main/Heart_disease_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/heart.xls')
df1.head(4)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0

# %%
df1.shape
# Out:
# (1025, 14)

# %%
df2 = pd.read_csv('/content/heart(2).xls')
df2.head(4)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1

# %%
df2['ChestPainType'].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df2['cp'] = df2['ChestPainType'].map({
    'ASY': 0,
    'ATA': 1,
    'NAP': 1,
    'TA': 1
})

# %%
df2['RestingECG_type'] = df2['RestingECG']

# %%
df2['RestingECG'] = df2['RestingECG'].map({
   'Normal': 0,
   'ST': 1,
   'LVH': 1
})

# %%
df2
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40   M           ATA        140          289          0           0
# 1     49   F           NAP        160          180          0           0
# 2     37   M           ATA        130          283          0           1
# 3     48   F           ASY        138          214          0           0
# 4     54   M           NAP        150          195          0           0
# ..   ...  ..           ...        ...          ...        ...         ...
# 913   45   M            TA        110          264          0           0
# 914   68   M           ASY        144          193          1           0
# 915   57   M           ASY        130          131          0           0
# 916   57   F           ATA        130          236          0           1
# 917   38   M           NAP        138          175          0           0
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  cp RestingECG_type
# ...

# %%
df_extra = [df1['ca'],df1['thal'],df2['ChestPainType'],df2['RestingECG_type']]

# %%
df1= df1.drop(['ca','thal'],axis=1)
df2= df2.drop(['ChestPainType','RestingECG_type'],axis=1)

# %%
df2
# Out:
#      Age Sex  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0     40   M        140          289          0           0    172
# 1     49   F        160          180          0           0    156
# 2     37   M        130          283          0           1     98
# 3     48   F        138          214          0           0    108
# 4     54   M        150          195          0           0    122
# ..   ...  ..        ...          ...        ...         ...    ...
# 913   45   M        110          264          0           0    132
# 914   68   M        144          193          1           0    141
# 915   57   M        130          131          0           0    115
# 916   57   F        130          236          0           1    174
# 917   38   M        138          175          0           0    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease  cp
# 0                N      0.0       Up             0   1
# ...

# %%
df1.columns = ['Age','Sex','cp','RestingBP','Cholesterol','FastingBS','RestingECG','MaxHR','ExerciseAngina','Oldpeak','ST_Slope','HeartDisease']

# %%
df = pd.concat([df1,df2])
df
# Out:
#      Age Sex  cp  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0     52   1   0        125          212          0           1    168
# 1     53   1   0        140          203          1           0    155
# 2     70   1   0        145          174          0           1    125
# 3     61   1   0        148          203          0           1    161
# 4     62   0   0        138          294          1           1    106
# ..   ...  ..  ..        ...          ...        ...         ...    ...
# 913   45   M   1        110          264          0           0    132
# 914   68   M   0        144          193          1           0    141
# 915   57   M   0        130          131          0           0    115
# 916   57   F   1        130          236          0           1    174
# 917   38   M   1        138          175          0           0    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0                0      1.0        2             0
# ...

# %% [markdown]
# # Encoding DF2

# %%
from sklearn.preprocessing import LabelEncoder

le= LabelEncoder()
df2['Sex'] = le.fit_transform(df2['Sex'])
df2['ExerciseAngina'] = le.fit_transform(df2['ExerciseAngina'])

# %%
df2['ST_Slope'].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df2['ST_Slope'] = df2['ST_Slope'].map({
    'Down': 0,
    'Flat': 0.5,
    'Up': 1
})

# %%
df2
# Out:
#      Age  Sex  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0     40    1        140          289          0           0    172
# 1     49    0        160          180          0           0    156
# 2     37    1        130          283          0           1     98
# 3     48    0        138          214          0           0    108
# 4     54    1        150          195          0           0    122
# ..   ...  ...        ...          ...        ...         ...    ...
# 913   45    1        110          264          0           0    132
# 914   68    1        144          193          1           0    141
# 915   57    1        130          131          0           0    115
# 916   57    0        130          236          0           1    174
# 917   38    1        138          175          0           0    173
#
#      ExerciseAngina  Oldpeak  ST_Slope  HeartDisease  cp
# 0                 0      0.0       1.0             0   1
# ...
